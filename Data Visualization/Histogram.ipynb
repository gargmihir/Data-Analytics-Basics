# %%
import numpy as np
from numpy.random import randn
import pandas as pd

# %%
from scipy import stats
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset1=randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  2.,   2.,   6.,  12.,  19.,  17.,  17.,   8.,  11.,   6.]),
#  array([-2.41162638, -1.97756439, -1.5435024 , -1.1094404 , -0.67537841,
#         -0.24131642,  0.19274558,  0.62680757,  1.06086956,  1.49493156,
#          1.92899355]),
#  <a list of 10 Patch objects>)

# %%
dataset2=randn(80)
plt.hist(dataset2,color='red')
# Out:
# (array([  2.,   2.,   5.,  13.,  16.,  19.,  14.,   6.,   2.,   1.]),
#  array([-2.78831821, -2.19653717, -1.60475613, -1.01297508, -0.42119404,
#          0.170587  ,  0.76236805,  1.35414909,  1.94593013,  2.53771118,
#          3.12949222]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,color='red',alpha=0.5,bins=20)
plt.hist(dataset2,normed=True,alpha=0.5,bins=20)
# Out:
# (array([ 0.04224535,  0.04224535,  0.04224535,  0.04224535,  0.08449071,
#          0.12673606,  0.25347213,  0.29571748,  0.29571748,  0.38020819,
#          0.59143496,  0.21122677,  0.33796284,  0.25347213,  0.16898142,
#          0.08449071,  0.04224535,  0.04224535,  0.        ,  0.04224535]),
#  array([-2.78831821, -2.49242769, -2.19653717, -1.90064665, -1.60475613,
#         -1.30886561, -1.01297508, -0.71708456, -0.42119404, -0.12530352,
#          0.170587  ,  0.46647752,  0.76236805,  1.05825857,  1.35414909,
#          1.65003961,  1.94593013,  2.24182065,  2.53771118,  2.8336017 ,
#          3.12949222]),
#  <a list of 20 Patch objects>)

# %%
data1=randn(1000)
data2=randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex',color='red')
